# %% [markdown]
# **Installation of dependencies**

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %% [markdown]
# **Cloning ultralyunics**

# %%
# !git --version
# Out:
# git version 2.33.1.windows.1

# %%
# !git init
# Out:
# Initialized empty Git repository in D:/Archive/Gun Knife/.git/

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %% [markdown]
# **installation according to requirements.txt**

# %%
# !cd yolov5 & pip install -r requirements.txt --user

# %% [markdown]
# **Modules installation**

# %%
pip install opencv-contrib-python

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# **Loading the model **

# %%
pip install numexpr
# Out:
# Requirement already satisfied: numexpr in c:\programdata\anaconda3\lib\site-packages (2.6.9)
# Requirement already satisfied: numpy>=1.7 in c:\users\abwao\appdata\roaming\python\python37\site-packages (from numexpr) (1.21.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\abwao/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-6-9 Python-3.9.7 torch-1.10.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1050, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# **Making detections with images**

# %%
img = 'https://easyreach.co.in/wp-content/uploads/2018/08/industrial-vehicle.jpg'

# %%
results = model(img)
results.imgs
# model(img)
# Out:
# [array([[[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 47,  55, 101],
#          [ 44,  52,  98],
#          [ 63,  71, 117]],
#
#         [[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 47,  55, 101],
#          [ 44,  52,  98],
#          [ 64,  72, 118]],
#
#         [[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 46,  54, 100],
#          [ 44,  52,  98],
#          [ 64,  72, 118]],
#
#         ...,
#
#         [[ 79,  75,  74],
#          [ 72,  68,  67],
#          [ 63,  59,  58],
#          ...,
#          [109,  85,  59],
#          [161, 137, 113],
#          [135, 113,  90]],
#
#         [[ 85,  81,  80],
#          [ 77,  73,  72],
#          [ 69,  65,  64],
#          ...,
#          [112,  88,  64],
#          [104,  82,  59],
#          [152, 130, 107]],
#
#         [[ 89,  85,  82],
#          [ 81,  77,  74],
#          [ 73,  69,  66],
#          ...,
#          [127, 105,  81],
#          [ 91,  69,  46],
#          [132, 110,  89]]], dtype=uint8)]

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 47,  55, 101],
#          [ 44,  52,  98],
#          [ 63,  71, 117]],
#
#         [[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 47,  55, 101],
#          [ 44,  52,  98],
#          [ 64,  72, 118]],
#
#         [[ 47,  51,  96],
#          [ 47,  51,  96],
#          [ 47,  51,  96],
#          ...,
#          [ 46,  54, 100],
#          [ 44,  52,  98],
#          [ 64,  72, 118]],
#
#         ...,
#
#         [[ 79,  75,  74],
#          [ 72,  68,  67],
#          [ 63,  59,  58],
#          ...,
#          [109,  85,  59],
#          [161, 137, 113],
#          [135, 113,  90]],
#
#         [[ 85,  81,  80],
#          [ 77,  73,  72],
#          [ 69,  65,  64],
#          ...,
#          [112,  88,  64],
#          [104,  82,  59],
#          [152, 130, 107]],
#
#         [[ 89,  85,  82],
#          [ 81,  77,  74],
#          [ 73,  69,  66],
#          ...,
#          [127, 105,  81],
#          [ 91,  69,  46],
#          [132, 110,  89]]], dtype=uint8)]

# %% [markdown]
# **Real time detection from webcam**

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# **Training**

# %%
pip install opencv-python>=4.1.2 --user
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python>=4.1.2 --user
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 20 --data data.yaml --weights yolov5s.pt --workers 2
# Out:
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'D:\Archive\Gun': No such file or directory
# YOLOv5  2022-5-31 Python-3.9.7 torch-1.10.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1050, 4096MiB)
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# 2022-05-31 13:22:05.359819: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-05-31 13:22:05.360781: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# wandb: wandb version 0.12.17 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# 2022-05-31 13:22:15.690283: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-05-31 13:22:15.690334: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# wandb: Tracking run with wandb version 0.12.6
# wandb: Syncing run dandy-capybara-12
# wandb:  View project at https://wandb.ai/barrito/train
# wandb:  View run at https://wandb.ai/barrito/train/runs/tx5q16u4
# wandb: Run data is saved locally in D:\Archive\Gun Knife\yolov5\wandb\run-20220531_132212-tx5q16u4
# wandb: Run `wandb offline` to turn off syncing.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   1%|          | 112k/14.1M [00:00<00:14, 995kB/s]
#   3%|2         | 384k/14.1M [00:00<00:07, 1.97MB/s]
#   6%|6         | 880k/14.1M [00:00<00:04, 3.11MB/s]
#  11%|#         | 1.52M/14.1M [00:00<00:02, 4.50MB/s]
#  16%|#6        | 2.31M/14.1M [00:00<00:02, 5.82MB/s]
#  23%|##3       | 3.25M/14.1M [00:00<00:01, 7.10MB/s]
#  29%|##8       | 4.06M/14.1M [00:00<00:01, 7.48MB/s]
#  35%|###4      | 4.92M/14.1M [00:00<00:01, 7.90MB/s]
#  42%|####2     | 5.98M/14.1M [00:00<00:00, 8.89MB/s]
#  48%|####8     | 6.84M/14.1M [00:01<00:00, 8.31MB/s]
#  56%|#####5    | 7.86M/14.1M [00:01<00:00, 8.86MB/s]
#  62%|######1   | 8.72M/14.1M [00:01<00:00, 8.53MB/s]
#  68%|######7   | 9.55M/14.1M [00:01<00:00, 6.71MB/s]
#  73%|#######2  | 10.2M/14.1M [00:01<00:00, 6.38MB/s]
#  77%|#######7  | 10.9M/14.1M [00:01<00:00, 6.18MB/s]
#  82%|########1 | 11.5M/14.1M [00:01<00:00, 6.20MB/s]
#  86%|########5 | 12.1M/14.1M [00:01<00:00, 6.11MB/s]
#  91%|######### | 12.8M/14.1M [00:02<00:00, 6.19MB/s]
#  95%|#########4| 13.4M/14.1M [00:02<00:00, 5.93MB/s]
# 100%|#########9| 14.1M/14.1M [00:02<00:00, 6.27MB/s]
# 100%|##########| 14.1M/14.1M [00:02<00:00, 6.49MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7022326 parameters, 7022326 gradients
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
#
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...:   0%|          | 0/2090 [00:00<?, ?it/s]Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\psutil\_common.py", line 447, in wrapper
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 40, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\Archive\Gun Knife\yolov5\val.py", line 37, in <module>
#     from models.common import DetectMultiBackend
#     from models.common import DetectMultiBackend
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#     from models.common import DetectMultiBackend
#     from models.common import DetectMultiBackend
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\Archive\Gun Knife\yolov5\models\common.py", line 24, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#     from utils.dataloaders import exif_transpose, letterbox
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#     from utils.dataloaders import exif_transpose, letterbox
#     from utils.dataloaders import exif_transpose, letterbox
#     from utils.dataloaders import exif_transpose, letterbox
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 29, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\augmentations.py", line 12, in <module>
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#   File "D:\Archive\Gun Knife\yolov5\utils\general.py", line 33, in <module>
#     import torchvision
#     import torchvision
#     import torchvision
#     import torchvision
#     import torchvision
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#     import torchvision
#     import torchvision
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py", line 7, in <module>
#     from torchvision import datasets
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from torchvision import datasets
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from torchvision import datasets
#     from torchvision import datasets
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from torchvision import datasets
#     from torchvision import datasets
#     from torchvision import datasets
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 13, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 13, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\__init__.py", line 9, in <module>
#     from .flickr import Flickr8k, Flickr30k
#     from .fakedata import FakeData
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\flickr.py", line 3, in <module>
#     from .fakedata import FakeData
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\fakedata.py", line 4, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\fakedata.py", line 4, in <module>
#     from .flickr import Flickr8k, Flickr30k
#     from .fakedata import FakeData
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\flickr.py", line 3, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\fakedata.py", line 4, in <module>
#     from .fakedata import FakeData
#     from .fakedata import FakeData
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\fakedata.py", line 4, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\fakedata.py", line 4, in <module>
#     ret = self._cache[fun]
# AttributeError: 'Process' object has no attribute '_cache'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\threading.py", line 973, in _bootstrap_inner
#     from html.parser import HTMLParser
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\html\__init__.py", line 6, in <module>
#     from html.parser import HTMLParser
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\html\__init__.py", line 6, in <module>
#     from .. import transforms
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\__init__.py", line 1, in <module>
#     from .. import transforms
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\__init__.py", line 2, in <module>
#     from .. import transforms
#     from .. import transforms
#     from .. import transforms
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\__init__.py", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\__init__.py", line 2, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\__init__.py", line 1, in <module>
#     from .autoaugment import *
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     from .transforms import *
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\transforms.py", line 16, in <module>
#     from .transforms import *
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     from .autoaugment import *
#     from .transforms import *
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# MemoryError
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# MemoryError
# MemoryError
# MemoryError
#     from . import functional as F
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\transforms\functional.py", line 19, in <module>
#     self.run()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\wandb\sdk\internal\stats.py", line 132, in _thread_body
#     from . import functional_tensor as F_t
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# MemoryError
#     stats = self.stats()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\wandb\sdk\internal\stats.py", line 185, in stats
#     in_use_by_us = gpu_in_use_by_this_process(handle)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\wandb\sdk\internal\stats.py", line 41, in gpu_in_use_by_this_process
#     base_process = psutil.Process().parent() or psutil.Process()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\psutil\__init__.py", line 546, in parent
#     from html.entities import html5 as _html5
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\html\entities.py", line 264, in <module>
#     from html.entities import html5 as _html5
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# MemoryError
#     ppid = self.ppid()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\psutil\_common.py", line 450, in wrapper
#     return fun(self)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\psutil\__init__.py", line 607, in ppid
#     self._ppid = self._ppid or self._proc.ppid()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\psutil\_pswindows.py", line 803, in ppid
#     return ppid_map()[self.pid]
# OSError: [WinError 1455] The paging file is too small for this operation to complete
#     html5 = {
# MemoryError
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_nvrtc.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_nvrtc.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
#
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   0%|          | 1/2090 [00:56<32:32:01, 56.07s/it]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...41 found, 0 missing, 0 empty, 0 corrupt:   2%|1         | 41/2090 [00:56<33:00,  1.03it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...60 found, 0 missing, 0 empty, 0 corrupt:   2%|1         | 41/2090 [01:19<33:00,  1.03it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...61 found, 0 missing, 0 empty, 0 corrupt:   3%|2         | 61/2090 [01:20<35:51,  1.06s/it]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...96 found, 0 missing, 0 empty, 0 corrupt:   5%|4         | 96/2090 [01:20<17:26,  1.90it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...123 found, 0 missing, 0 empty, 0 corrupt:   6%|5         | 123/2090 [01:20<11:18,  2.90it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...140 found, 0 missing, 0 empty, 0 corrupt:   7%|6         | 140/2090 [01:21<08:43,  3.72it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...157 found, 0 missing, 0 empty, 0 corrupt:   8%|7         | 157/2090 [01:21<06:40,  4.82it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...166 found, 0 missing, 0 empty, 0 corrupt:   8%|7         | 166/2090 [01:22<06:03,  5.29it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...201 found, 0 missing, 0 empty, 0 corrupt:  10%|9         | 201/2090 [01:22<03:10,  9.91it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...214 found, 0 missing, 0 empty, 0 corrupt:  10%|#         | 214/2090 [01:23<02:36, 11.97it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...225 found, 0 missing, 0 empty, 0 corrupt:  11%|#         | 225/2090 [01:23<02:11, 14.22it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...235 found, 0 missing, 0 empty, 0 corrupt:  11%|#1        | 235/2090 [01:23<01:49, 16.98it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...245 found, 0 missing, 0 empty, 0 corrupt:  12%|#1        | 245/2090 [01:23<01:29, 20.69it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...254 found, 0 missing, 0 empty, 0 corrupt:  12%|#2        | 254/2090 [01:23<01:17, 23.67it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...265 found, 0 missing, 0 empty, 0 corrupt:  13%|#2        | 265/2090 [01:23<01:01, 29.82it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...273 found, 0 missing, 0 empty, 0 corrupt:  13%|#3        | 273/2090 [01:24<00:58, 30.95it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...284 found, 0 missing, 0 empty, 0 corrupt:  14%|#3        | 284/2090 [01:24<00:47, 38.02it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...294 found, 0 missing, 0 empty, 0 corrupt:  14%|#4        | 294/2090 [01:24<00:40, 44.00it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...304 found, 0 missing, 0 empty, 0 corrupt:  15%|#4        | 304/2090 [01:24<00:34, 52.36it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...312 found, 0 missing, 0 empty, 0 corrupt:  15%|#4        | 312/2090 [01:24<00:31, 56.99it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...320 found, 0 missing, 0 empty, 0 corrupt:  15%|#5        | 320/2090 [01:24<00:39, 44.68it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...336 found, 0 missing, 0 empty, 0 corrupt:  16%|#6        | 336/2090 [01:25<00:29, 59.81it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...344 found, 0 missing, 0 empty, 0 corrupt:  16%|#6        | 344/2090 [01:25<00:30, 57.00it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...354 found, 0 missing, 0 empty, 0 corrupt:  17%|#6        | 354/2090 [01:25<00:28, 60.87it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...361 found, 0 missing, 0 empty, 0 corrupt:  17%|#7        | 361/2090 [01:25<00:29, 58.23it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...372 found, 0 missing, 0 empty, 0 corrupt:  18%|#7        | 372/2090 [01:25<00:27, 63.37it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...379 found, 0 missing, 0 empty, 0 corrupt:  18%|#8        | 379/2090 [01:25<00:32, 51.91it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...385 found, 0 missing, 0 empty, 0 corrupt:  18%|#8        | 385/2090 [01:25<00:33, 50.76it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...391 found, 0 missing, 0 empty, 0 corrupt:  19%|#8        | 391/2090 [01:26<00:33, 51.25it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...403 found, 0 missing, 0 empty, 0 corrupt:  19%|#9        | 403/2090 [01:26<00:26, 62.76it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...410 found, 0 missing, 0 empty, 0 corrupt:  20%|#9        | 410/2090 [01:26<00:31, 53.40it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...420 found, 0 missing, 0 empty, 0 corrupt:  20%|##        | 420/2090 [01:26<00:26, 63.15it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...427 found, 0 missing, 0 empty, 0 corrupt:  20%|##        | 427/2090 [01:26<00:27, 59.91it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...435 found, 0 missing, 0 empty, 0 corrupt:  21%|##        | 435/2090 [01:26<00:27, 59.92it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...442 found, 0 missing, 0 empty, 0 corrupt:  21%|##1       | 442/2090 [01:27<00:43, 38.04it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...466 found, 0 missing, 0 empty, 0 corrupt:  22%|##2       | 466/2090 [01:27<00:27, 58.94it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...480 found, 0 missing, 0 empty, 0 corrupt:  23%|##2       | 480/2090 [01:27<00:24, 64.74it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...491 found, 0 missing, 0 empty, 0 corrupt:  23%|##3       | 491/2090 [01:27<00:22, 71.62it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...505 found, 0 missing, 0 empty, 0 corrupt:  24%|##4       | 505/2090 [01:27<00:22, 71.85it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...516 found, 0 missing, 0 empty, 0 corrupt:  25%|##4       | 516/2090 [01:27<00:20, 77.80it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...525 found, 0 missing, 0 empty, 0 corrupt:  25%|##5       | 525/2090 [01:28<00:19, 80.31it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...534 found, 0 missing, 0 empty, 0 corrupt:  26%|##5       | 534/2090 [01:28<00:19, 80.77it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...543 found, 0 missing, 0 empty, 0 corrupt:  26%|##5       | 543/2090 [01:28<00:19, 79.31it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...558 found, 0 missing, 0 empty, 0 corrupt:  27%|##6       | 558/2090 [01:28<00:16, 94.92it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...570 found, 0 missing, 0 empty, 0 corrupt:  27%|##7       | 570/2090 [01:28<00:15, 98.43it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...582 found, 0 missing, 0 empty, 0 corrupt:  28%|##7       | 582/2090 [01:28<00:17, 84.17it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...597 found, 0 missing, 0 empty, 0 corrupt:  29%|##8       | 597/2090 [01:28<00:18, 82.57it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...611 found, 0 missing, 0 empty, 0 corrupt:  29%|##9       | 611/2090 [01:29<00:16, 87.68it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...625 found, 0 missing, 0 empty, 0 corrupt:  30%|##9       | 625/2090 [01:29<00:14, 99.22it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...637 found, 0 missing, 0 empty, 0 corrupt:  30%|###       | 637/2090 [01:29<00:14, 99.13it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...654 found, 0 missing, 0 empty, 0 corrupt:  31%|###1      | 654/2090 [01:29<00:13, 108.45it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...666 found, 0 missing, 0 empty, 0 corrupt:  32%|###1      | 666/2090 [01:29<00:13, 104.24it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...679 found, 0 missing, 0 empty, 0 corrupt:  32%|###2      | 679/2090 [01:29<00:13, 107.92it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...692 found, 0 missing, 0 empty, 0 corrupt:  33%|###3      | 692/2090 [01:29<00:12, 111.58it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...704 found, 0 missing, 0 empty, 0 corrupt:  34%|###3      | 704/2090 [01:30<00:18, 74.71it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...714 found, 0 missing, 0 empty, 0 corrupt:  34%|###4      | 714/2090 [01:30<00:21, 63.58it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...722 found, 0 missing, 0 empty, 0 corrupt:  35%|###4      | 722/2090 [01:30<00:20, 66.32it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...730 found, 0 missing, 0 empty, 0 corrupt:  35%|###4      | 730/2090 [01:30<00:21, 63.73it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...739 found, 0 missing, 0 empty, 0 corrupt:  35%|###5      | 739/2090 [01:30<00:19, 68.35it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...747 found, 0 missing, 0 empty, 0 corrupt:  36%|###5      | 747/2090 [01:30<00:20, 65.50it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...755 found, 0 missing, 0 empty, 0 corrupt:  36%|###6      | 755/2090 [01:30<00:24, 53.64it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...761 found, 0 missing, 0 empty, 0 corrupt:  36%|###6      | 761/2090 [01:31<00:24, 54.43it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...770 found, 0 missing, 0 empty, 0 corrupt:  37%|###6      | 770/2090 [01:31<00:24, 53.43it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...787 found, 0 missing, 0 empty, 0 corrupt:  38%|###7      | 787/2090 [01:31<00:26, 49.21it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...801 found, 0 missing, 0 empty, 0 corrupt:  38%|###8      | 801/2090 [01:31<00:20, 63.69it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...814 found, 0 missing, 0 empty, 0 corrupt:  39%|###8      | 814/2090 [01:31<00:17, 74.14it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...823 found, 0 missing, 0 empty, 0 corrupt:  39%|###9      | 823/2090 [01:32<00:19, 63.52it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...846 found, 0 missing, 0 empty, 0 corrupt:  40%|####      | 846/2090 [01:32<00:14, 84.01it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...868 found, 0 missing, 0 empty, 0 corrupt:  42%|####1     | 868/2090 [01:32<00:11, 109.48it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...886 found, 0 missing, 0 empty, 0 corrupt:  42%|####2     | 886/2090 [01:32<00:12, 96.48it/s]
# train: Scanning 'D:\Archive\Gun Knife\data\train\labels' images and labels...898 found, 0 missing, 0 empty, 0 corrupt:  43%|####2     | 898/2090 [01:32<00:11, 99.91it/s]
# ...
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
#
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...311 found, 0 missing, 0 empty, 0 corrupt:  52%|#####2    | 311/597 [00:24<00:03, 79.02it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...321 found, 0 missing, 0 empty, 0 corrupt:  54%|#####3    | 321/597 [00:24<00:03, 82.76it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...330 found, 0 missing, 0 empty, 0 corrupt:  55%|#####5    | 330/597 [00:24<00:03, 80.27it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...340 found, 0 missing, 0 empty, 0 corrupt:  57%|#####6    | 340/597 [00:24<00:03, 84.82it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...349 found, 0 missing, 0 empty, 0 corrupt:  58%|#####8    | 349/597 [00:24<00:03, 79.87it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...358 found, 0 missing, 0 empty, 0 corrupt:  60%|#####9    | 358/597 [00:24<00:02, 79.79it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...367 found, 0 missing, 0 empty, 0 corrupt:  61%|######1   | 367/597 [00:24<00:03, 66.33it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...377 found, 0 missing, 0 empty, 0 corrupt:  63%|######3   | 377/597 [00:25<00:02, 73.83it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
#
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...386 found, 0 missing, 0 empty, 0 corrupt:  65%|######4   | 386/597 [00:25<00:02, 74.96it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...395 found, 0 missing, 0 empty, 0 corrupt:  66%|######6   | 395/597 [00:25<00:02, 78.12it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...405 found, 0 missing, 0 empty, 0 corrupt:  68%|######7   | 405/597 [00:25<00:02, 83.11it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...415 found, 0 missing, 0 empty, 0 corrupt:  70%|######9   | 415/597 [00:25<00:02, 86.10it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...424 found, 0 missing, 0 empty, 0 corrupt:  71%|#######1  | 424/597 [00:25<00:02, 72.97it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...432 found, 0 missing, 0 empty, 0 corrupt:  72%|#######2  | 432/597 [00:25<00:02, 63.73it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...441 found, 0 missing, 0 empty, 0 corrupt:  74%|#######3  | 441/597 [00:25<00:02, 68.29it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...449 found, 0 missing, 0 empty, 0 corrupt:  75%|#######5  | 449/597 [00:26<00:02, 69.34it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...457 found, 0 missing, 0 empty, 0 corrupt:  77%|#######6  | 457/597 [00:26<00:01, 71.79it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...465 found, 0 missing, 0 empty, 0 corrupt:  78%|#######7  | 465/597 [00:26<00:01, 73.71it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
#
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...474 found, 0 missing, 0 empty, 0 corrupt:  79%|#######9  | 474/597 [00:26<00:01, 77.07it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...482 found, 0 missing, 0 empty, 0 corrupt:  81%|########  | 482/597 [00:26<00:01, 75.44it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...490 found, 0 missing, 0 empty, 0 corrupt:  82%|########2 | 490/597 [00:26<00:01, 74.45it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...498 found, 0 missing, 0 empty, 0 corrupt:  83%|########3 | 498/597 [00:26<00:01, 71.77it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...507 found, 0 missing, 0 empty, 0 corrupt:  85%|########4 | 507/597 [00:26<00:01, 72.19it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...515 found, 0 missing, 0 empty, 0 corrupt:  86%|########6 | 515/597 [00:26<00:01, 72.97it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...523 found, 0 missing, 0 empty, 0 corrupt:  88%|########7 | 523/597 [00:27<00:01, 66.91it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...533 found, 0 missing, 0 empty, 0 corrupt:  89%|########9 | 533/597 [00:27<00:00, 75.06it/s]    main_content = runpy.run_path(main_path,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 26, in <module>
#     import torch
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 124, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
#
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...544 found, 0 missing, 0 empty, 0 corrupt:  91%|#########1| 544/597 [00:27<00:00, 82.98it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...553 found, 0 missing, 0 empty, 0 corrupt:  93%|#########2| 553/597 [00:27<00:00, 81.30it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...563 found, 0 missing, 0 empty, 0 corrupt:  94%|#########4| 563/597 [00:27<00:00, 82.31it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...574 found, 0 missing, 0 empty, 0 corrupt:  96%|#########6| 574/597 [00:27<00:00, 89.05it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...584 found, 0 missing, 0 empty, 0 corrupt:  98%|#########7| 584/597 [00:27<00:00, 88.44it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...593 found, 0 missing, 0 empty, 0 corrupt:  99%|#########9| 593/597 [00:27<00:00, 84.68it/s]
# val: Scanning 'D:\Archive\Gun Knife\data\valid\labels' images and labels...597 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 597/597 [00:27<00:00, 21.39it/s]
# val: New cache created: D:\Archive\Gun Knife\data\valid\labels.cache
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# wandb: Currently logged in as: barrito (use `wandb login --relogin` to force relogin)
# Plotting labels to runs\train\exp\labels.jpg...
#
# AutoAnchor: 4.38 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs\train\exp
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/131 [00:00<?, ?it/s]
#       0/19    0.805G    0.1207   0.01371         0        35       320:   0%|          | 0/131 [00:02<?, ?it/s]
#       0/19    0.805G    0.1207   0.01371         0        35       320:   1%|          | 1/131 [00:05<11:46,  5.43s/it]
#       0/19    0.833G     0.124    0.0137         0        34       320:   1%|          | 1/131 [00:05<11:46,  5.43s/it]
#       0/19    0.833G     0.124    0.0137         0        34       320:   2%|1         | 2/131 [00:05<05:25,  2.52s/it]
#       0/19    0.833G     0.124    0.0137         0        34       320:   2%|1         | 2/131 [00:05<06:21,  2.96s/it]
# Traceback (most recent call last):
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 670, in <module>
#     main(opt)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 565, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "D:\Archive\Gun Knife\yolov5\train.py", line 326, in train
#     for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\tqdm\std.py", line 1180, in __iter__
#     for obj in iterable:
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 158, in __iter__
#     yield next(self.iterator)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py", line 521, in __next__
#     data = self._next_data()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py", line 1203, in _next_data
#     return self._process_data(data)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py", line 1229, in _process_data
#     data.reraise()
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_utils.py", line 433, in reraise
#     raise RuntimeError(msg) from None
# RuntimeError: Caught MemoryError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\worker.py", line 287, in _worker_loop
#     data = fetcher.fetch(index)
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 587, in __getitem__
#     img, labels = self.load_mosaic(index)
#   File "D:\Archive\Gun Knife\yolov5\utils\dataloaders.py", line 691, in load_mosaic
#     img4 = np.full((s * 2, s * 2, img.shape[2]), 114, dtype=np.uint8)  # base image with 4 tiles
#   File "C:\Users\abwao\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\numeric.py", line 342, in full
#     a = empty(shape, dtype, order)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.17 MiB for an array with shape (640, 640, 3) and data type uint8
#
# wandb: Waiting for W&B process to finish, PID 17720... (failed 1). Press ctrl-c to abort syncing.
# wandb: - 0.00MB of 0.00MB uploaded (0.00MB deduped)
# wandb: \ 0.00MB of 0.00MB uploaded (0.00MB deduped)
# wandb: | 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: / 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: - 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: \ 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: | 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: / 0.00MB of 0.01MB uploaded (0.00MB deduped)
# wandb: - 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: \ 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: | 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: / 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: - 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: \ 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: | 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: / 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: - 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb: \ 0.01MB of 0.01MB uploaded (0.00MB deduped)
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dandy-capybara-12: https://wandb.ai/barrito/train/runs/tx5q16u4
# wandb: Find logs at: .\wandb\run-20220531_132212-tx5q16u4\logs\debug.log
# wandb:

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp11/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\abwao/.cache\torch\hub\master.zip
# YOLOv5  2022-7-11 Python-3.9.7 torch-1.10.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1050, 4096MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients
# Adding AutoShape...

# %%
# img = 'https://bulletsfirst.net/wp-content/uploads/2014/10/black-guy-with-gun.jpg'
# img = 'https://fscomps.fotosearch.com/compc/CSP/CSP292/close-up-of-a-businessman-holding-a-gun-stock-photo__k17669467.jpg'
# img = 'https://thumbs.dreamstime.com/z/horror-firearms-topic-suicide-gun-gray-background-studio-61089195.jpg'
# img = 'http://www.milwaukeeindependent.com/wp-content/uploads/2017/09/goodguywihgunalt.jpg'
# img = 'https://nationalinterest.org/sites/default/files/main_images/1620px-Decisive_Action_Rotation_13-04_130218-A-ML570-001.jpg'
# img = 'https://www.khaama.com/wp-content/uploads/2017/04/US-soldier-Afghanistan.jpg'
img = '1.jpg'
img2 = 'DSC_00301_JPG.rf.a44e4b363a7beea921c82b92e11c51c8.jpg'

# %%
# !cd yolov5 && python detect.py --conf 0.5
# Out:
# detect: weights=yolov5s.pt, source=data\images, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: opencv-python>=4.1.2 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install opencv-python>=4.1.2' skipped (offline)
# YOLOv5  2021-11-9 torch 1.10.0+cu102 CUDA:0 (GeForce GTX 1050, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 D:\Archive\Gun Det\yolov5\data\images\bus.jpg: 640x480 3 persons, 1 bus, Done. (0.021s)
# image 2/2 D:\Archive\Gun Det\yolov5\data\images\zidane.jpg: 384x640 2 persons, 1 tie, Done. (0.031s)
# Speed: 3.3ms pre-process, 25.9ms inference, 378.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp8

# %%
results = model(img)
pred2 = model(img2)
results.pred[0]
print(len(results.pred[0]))

# model(img)
# Out:
# 1

# %%
# %matplotlib inline 
plt.figure(figsize=(10,10))
for i in range(2):
    plt.subplot(2,2, i + 1 )
    plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.pred
# Out:
# [tensor([[219.22818, 292.01773, 255.23018, 324.08304,   0.90462,   1.00000]], device='cuda:0')]

# %%
classy = round(results.pred[0][0][5].tolist())
classy

if classy == 0:
    print("Gun detected")
elif classy == 1:
    print("Knife detected")
# Out:
# Gun detected

# %%
img1 = cv2.imread(img)

# %%
# %matplotlib inline 
plt.imshow(img1)
plt.show()

# %%
x, y, w, h = np.array(results.pred[0][0][:4].tolist())*0.93

# %%
confidence = results.pred[0][0][4].tolist()
print(confidence)
# Out:
# 0.935546875

# %%
font = cv2.FONT_HERSHEY_PLAIN
label = 'gun'
# x, y, w, h = results.pred[0][0][:4].tolist()
x, y, w, h = int(x), int(y), int(w),int(h)

confidence = results.pred[0][0][4].tolist()
color = (0, 0, 255)
cv2.rectangle(img1, (x, y), (x + w, y + h), color, 2)
cv2.putText(img1, label + " {0:.1%}".format(confidence), (x, y - 20),font, 3, color, 3)
# Out:
# array([[[193, 145,  81],
#         [193, 145,  81],
#         [193, 145,  81],
#         ...,
#         [ 67,  84, 111],
#         [ 66,  83, 110],
#         [ 69,  86, 113]],
#
#        [[193, 145,  81],
#         [193, 145,  81],
#         [193, 145,  81],
#         ...,
#         [ 69,  86, 113],
#         [ 64,  81, 108],
#         [ 61,  78, 105]],
#
#        [[194, 146,  82],
#         [194, 146,  82],
#         [194, 146,  82],
#         ...,
#         [ 75,  92, 118],
#         [ 64,  84, 109],
#         [ 57,  77, 102]],
#
#        ...,
#
#        [[ 59,  83, 111],
#         [ 96, 119, 145],
#         [124, 146, 171],
#         ...,
#         [ 50,  55,  58],
#         [ 48,  53,  56],
#         [ 54,  59,  62]],
#
#        [[ 94, 118, 146],
#         [151, 174, 200],
#         [135, 157, 182],
#         ...,
#         [ 50,  55,  58],
#         [ 49,  54,  57],
#         [ 58,  63,  66]],
#
#        [[102, 126, 154],
#         [121, 144, 170],
#         [ 65,  87, 112],
#         ...,
#         [ 42,  47,  50],
#         [ 38,  43,  46],
#         [ 45,  50,  53]]], dtype=uint8)

# %%
# %matplotlib inline 
plt.imshow(img1)
plt.show()

# %%
results.pred[0][0][:4].tolist()
# Out:
# [1509.34814453125, 63.761722564697266, 1668.5047607421875, 494.8423767089844]

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture('last_Trim.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    
    cv2.imshow('Real time gun detection', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3308/3986491847.py in <module>
#       4
#       5     # Make detections
# ----> 6     results = model(frame)
#       7
#       8
#
# c:\users\abwao\appdata\local\programs\python\python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\abwao\appdata\local\programs\python\python39\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py in forward(self, imgs, size, augment, profile)
#     592                 im, f = np.asarray(exif_transpose(im)), getattr(im, 'filename', f) or f
#     593             files.append(Path(f).with_suffix('.jpg').name)
# --> 594             if im.shape[0] < 5:  # image in CHW
#     595                 im = im.transpose((1, 2, 0))  # reverse dataloader .transpose(2, 0, 1)
#     596             im = im[..., :3] if im.ndim == 3 else np.tile(im[..., None], 3)  # enforce 3ch input
#
# AttributeError: 'NoneType' object has no attribute 'shape'
